# %%
import sys
import os

# In Jupyter, __file__ is not defined. Use the current working directory instead.
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# %%
from util.fetch import fetch_url
from bs4 import BeautifulSoup
import pandas as pd

# %%
base_url = "https://ssisports.net"

# %%
url = "https://ssisports.net/Categories/Index"

content = fetch_url(url)
# Out:
# Status Code: 200

# %%
soup = BeautifulSoup(content, 'html.parser')

# %%
categories = soup.find_all(class_='brand-section')

len(categories)
# Out:
# 16

# %%
category_list = []

for category in categories:
    cat = category.find('h1').text.strip()
    sub_cats_html = category.find_all(class_='brand-section-brand')

    sub_cat_list = []
    for sub_cat in sub_cats_html:
        a_tag = sub_cat.find('a')
        if a_tag:
            sub_cat_name = a_tag.text.strip()
            sub_cat_url = a_tag['href']
            # print(sub_cat_name, sub_cat_url)
            sub_cat_list.append({
                "category": cat,
                "sub_category": sub_cat_name,
                "url": sub_cat_url
            })
    category_list.extend(sub_cat_list)
    print(f"Collected {len(sub_cat_list)} from {cat}")
# Out:
# Collected 8 from Apparel
# Collected 6 from Archery
# Collected 8 from Camping and Outdoor
# Collected 9 from Fishing
# Collected 3 from Gifts and Novelty
# Collected 4 from Golf
# Collected 0 from Houseware
# Collected 7 from Hunting
# Collected 6 from Knives and Tools
# Collected 3 from Lights
# Collected 4 from Marine and Water Sports
# Collected 1 from Nightvision and Thermal
# Collected 10 from Optics and Sights
# Collected 3 from Public Safety and LE
# Collected 31 from Shooting
# Collected 2 from Sports

# %%
from util.file import save_json_to_dir, load_json_from_dir

# %%
save_json_to_dir(category_list, "ssi.json")

# %%
loaded=load_json_from_dir("ssi.json")

category_list == loaded
# Out:
# True

# %%
from scraper.ssi import scrape_ssi

# %%
dfs = {}
for i, c in enumerate(category_list,1):
    # print(i)
    print(c)
    url = f"{base_url}{c.get('url')}"
    df = scrape_ssi(url)
    df['category'] = c.get('category')
    df['sub_category'] = c['sub_category'].split('(')[0].strip()
    dfs[i] = df
    # break
# Out:
# {'category': 'Apparel', 'sub_category': 'Bottoms (1)', 'url': '/Categories/List/Bottoms'}
# Status Code: 200
# Product 1:
#   Name: 5.11 Tactical Stryke Pant w/Flex-Tac -TDU Green  Size 32-32
#   SKU: 1108232
# {'category': 'Apparel', 'sub_category': 'Eyewear - Accessories (12)', 'url': '/Categories/List/Eyewear-Accessories'}
# Status Code: 200
# Product 1:
#   Name: ESS Crosshair Replacement Lens Smoke Gray
#   SKU: 1121604
# Product 2:
#   Name: ESS Nomex Heat Sleeve
#   SKU: 1121609
# Product 3:
#   Name: ESS Crossbow Replacement Lens Hi-Def Yellow
#   SKU: 1121597
# Product 4:
#   Name: ESS Eyewear Profile NVG Hi-Def Yelllow Rep Lens 740-0121
#   SKU: 311926
# Product 5:
#   Name: ESS Eyewear ICE NARO Frame and Nosepiece Kit 740-0083
#   SKU: 312107
# Product 6:
#   Name: ESS CrossBlade ONE Eyeshield Smoke Gray
#   SKU: 1121612
# Product 7:
#   Name: ESS Eyewear Ice 2X Eyeshield Kit 740-0003
#   SKU: 312428
# Product 8:
#   Name: ESS CDI Replacement Lens Smoke Gray
#   SKU: 1121608
# Product 9:
#   Name: ESS Crossbow Gasket
#   SKU: 1121593
# ERRROR accessing stock 'span.contents[2].text.strip()' in <div class="product-details-available">
# <span class="text-danger"><b>Available:</b> 0</span>
# </div>
# Product 10:
#   Name: ESS Crossbow Replacement Lens Smoke Gray
#   SKU: 1121598
# ERRROR accessing stock 'span.contents[2].text.strip()' in <div class="product-details-available">
# <span class="text-danger"><b>Available:</b> 0</span>
# </div>
# Product 11:
#   Name: ESS Crossbow Replacement Lens Clear
#   SKU: 1121599
# ERRROR accessing stock 'span.contents[2].text.strip()' in <div class="product-details-available">
# <span class="text-danger"><b>Available:</b> 0</span>
# </div>
# Product 12:
#   Name: ESS Crossbow Replacement Nosepiece
#   SKU: 1121607
# ERRROR accessing stock 'span.contents[2].text.strip()' in <div class="product-details-available">
# <span class="text-danger"><b>Available:</b> 0</span>
# </div>
# {'category': 'Apparel', 'sub_category': 'Eyewear - Goggles (2)', 'url': '/Categories/List/Eyewear-Goggles'}
# Status Code: 200
# Product 1:
#   Name: ESS Striketeam SJ Goggle
#   SKU: 1121610
# Product 2:
#   Name: ESS Eyewear Profile Goggles Black 740-0499
#   SKU: 318710
# {'category': 'Apparel', 'sub_category': 'Eyewear - Safety and Shooting (34)', 'url': '/Categories/List/Eyewear-Safety-and-Shooting'}
# Status Code: 200
# Product 1:
#   Name: Howard Leight Range Eyewear XV100 Series Protective Eyewear
#   SKU: 1134053
# Product 2:
#   Name: Lyman Eye Protection 3 Pack
#   SKU: 4019086
# Product 3:
#   Name: Pyramex Intruder Clear Frame Clear Hardcoated Lens 12pk
#   SKU: 1128981
# Product 4:
#   Name: Walkers Premium Shooting Glasses Clear
#   SKU: 1125732
# Product 5:
#   Name: ESS Crossbow Suppressor One Gray
#   SKU: 1121605
# Product 6:
#   Name: ESS Eyewear Crossbow Suppressor ONE Kit 740-0472
#   SKU: 317249
# Product 7:
#   Name: ESS CDI and CDI MAX Replacement Temple Sleeves
#   SKU: 1150520
# Product 8:
#   Name: Walkers Premium Shooting Glasses Vermillion
#   SKU: 1125734
# Product 9:
#   Name: Pyramex Ztek Safety Glasses Clear Frame Clear AntiFog Lens
#   SKU: 1130374
# Product 10:
#   Name: ESS ICE-One Ballistic Eyeshield-Clear Lens White 2.4
#   SKU: 1150509
# Product 11:
#   Name: ESS ICE Replacement Lens
#   SKU: 1150517
# Product 12:
#   Name: ESS ICE and NARO Semi-Rigid Protective Case
#   SKU: 1150522
# Product 13:
#   Name: ESS Goggle Speed Sleeves
#   SKU: 1150525
# Product 14:
#   Name: ESS CDI Ballistic Eyeshield-Black
#   SKU: 1150510
# Product 15:
#   Name: ESS Firepro 1977 Asian Fit Goggle Anti-Fog Scratch-Resistant
#   SKU: 1150511
# Product 16:
#   Name: ESS Replacement Lens CDI MAX-Mirrored Silver-One Size
#   SKU: 1150524
# Product 17:
#   Name: ESS Eyeshield Hard Case
#   SKU: 1150506
# Product 18:
#   Name: ESS Replacement LensScratch Resistant Polarized-Smoke Gray
#   SKU: 1150515
# Product 19:
#   Name: ESS Eyewear Crossbow Suppressor 2X Kit 740-0475
#   SKU: 317409
# Product 20:
#   Name: ESS Replacement Lens Crosshair-Clear
#   SKU: 1150514
# Product 21:
#   Name: ESS Profile Pivot Strap Assembly
#   SKU: 1150516
# Product 22:
#   Name: ESS Eyewear Cross Series Crossbow 2X Kit  740-0504
#   SKU: 318765
# Product 23:
#   Name: ESS Crossbow Tri-Tech Fit Frame Kit
#   SKU: 1150505
# Product 24:
#   Name: ESS Crossbow Suppressor Frame Kit
#   SKU: 1150513
# Product 25:
#   Name: ESS Sunglasses Crossbow Surpressor ONE-Black w Clear Lens
#   SKU: 1150507
# {'category': 'Apparel', 'sub_category': 'Eyewear - Sunglasses (14)', 'url': '/Categories/List/Eyewear-Sunglasses'}
# Status Code: 200
# Product 1:
#   Name: Oakley SI Cohort Blackside w Prizm Black Pol
#   SKU: 1131595
# Product 2:
#   Name: Poptical Popgun Sunglasses Matte Black/Gray-Blue Mirror Polarized
#   SKU: 1129345
# Product 3:
#   Name: Poptical Popgun Sunglasses Matte Black / Brown Polarized
#   SKU: 1129343
# Product 4:
#   Name: Poptical Popart Sunglasses Matte Black / Gray/Green Mirror
#   SKU: 1129344
# Product 5:
#   Name: Poptical Popgear Sunglasses Matte Black/Gray Polarized
#   SKU: 1129346
# Product 6:
#   Name: Poptical PopH2O Sunglasses Matte Black Gray-Green Mirror Polarized
#   SKU: 1129349
# Product 7:
#   Name: Poptical PopTrail Sunglasses Matte Black Gray Polarized Sm
#   SKU: 1129354
# Product 8:
#   Name: Poptical PopTrail Sunglasses Gray/Orange w/Orange Mirror Polarized Sm
#   SKU: 1129356
# Product 9:
#   Name: Poptical PopEdge Sunglasses Gloss Black Red Mirror Polarized Small
#   SKU: 1129355
# Product 10:
#   Name: Poptical Popgun Sunglasses Gloss Black-Grn Crystal/Gray-Grn Mirror
#   SKU: 1129351
# Product 11:
#   Name: Poptical Popgear Sunglasses Gloss Black over Crystal Gray Polarized
#   SKU: 1129352
# Product 12:
#   Name: Poptical Popstorm Sunglasses Gloss Black / Brown Polarized
#   SKU: 1129347
# Product 13:
#   Name: Poptical Popstorm Sunglasses Gloss Black-Green Crystal / Gray
#   SKU: 1129348
# Product 14:
#   Name: Oakley SI Ballistic M Frame 3.0 Blk Array Clear Grey Per
#   SKU: 1131565
# {'category': 'Apparel', 'sub_category': 'Gloves (4)', 'url': '/Categories/List/Gloves'}
# Status Code: 200
# Product 1:
#   Name: Mechanix Azimuth Tactical Combat Glove Black Medium
#   SKU: 9004879
# Product 2:
#   Name: Mechanix Azimuth Tactical Combat Glove Black Large
#   SKU: 9004874
# Product 3:
#   Name: Seirus HWS Workman Xtreme Mens Glove Gauntlet Kevlar-Blk-Md
#   SKU: 4011677
# Product 4:
#   Name: Mechanix Azimuth Tactical Combat Glove Black Small
#   SKU: 9004881
# {'category': 'Apparel', 'sub_category': 'Headwear (5)', 'url': '/Categories/List/Headwear'}
# Status Code: 200
# Product 1:
#   Name: BunkerHead Mossyoak Breakup Bugmesh System
#   SKU: 1119743
# Product 2:
#   Name: BunkerHead Realtree Xtra Leafy and Cotton System
#   SKU: 1119750
# Product 3:
#   Name: BunkerHead Mossyoak Breakup Infinity Cotton System
#   SKU: 1119745
# Product 4:
#   Name: BunkerHead Realtree AP Fleece System
#   SKU: 1119747
# Product 5:
#   Name: BunkerHead Hillcountry Camo Cotton System
#   SKU: 1119753
# {'category': 'Apparel', 'sub_category': 'Tops (11)', 'url': '/Categories/List/Tops'}
# Status Code: 200
# Product 1:
#   Name: Under Armour Tac Range Polo Small Black
#   SKU: 5017260
# ERROR accessing price '.h3.text.strip()' in <div class="product-details-price">
# <small class="text-dark">Dealer Price:</small>
# </div>
# Product 2:
#   Name: 5.11 Rapid Response LS Shirt Volcanic SM 72430098SM
#   SKU: 5016166
# ERROR accessing price '.h3.text.strip()' in <div class="product-details-price">
# <small class="text-dark">Dealer Price:</small>
# </div>
# Product 3:
#   Name: 5.11 Rapid Response LS Shirt Silver Pine 2XL 724308002XL
#   SKU: 5016175
# ERROR accessing price '.h3.text.strip()' in <div class="product-details-price">
# <small class="text-dark">Dealer Price:</small>
# </div>
# Product 4:
#   Name: Under Armour Tevo 14 Zip Shirt Rt Xtra Med 1259131-946-MD
#   SKU: 5017326
# ERROR accessing price '.h3.text.strip()' in <div class="product-details-price">
# <small class="text-dark">Dealer Price:</small>
# </div>
# Product 5:
#   Name: 5.11 Rapid Response LS Shirt Sage Green SM 72430831SM
#   SKU: 5016176
# ERROR accessing price '.h3.text.strip()' in <div class="product-details-price">
# <small class="text-dark">Dealer Price:</small>
# </div>
# Product 6:
#   Name: Under Armour Artemis Hybrid Wms Jacket Rt Xtra Lg 1282685-94
#   SKU: 5017343
# ERROR accessing price '.h3.text.strip()' in <div class="product-details-price">
# <small class="text-dark">Dealer Price:</small>
# </div>
# Product 7:
#   Name: Under Armour Artemis Hybrid Wms Jacket Rt Xtra Med 1282685-9
#   SKU: 5017342
# ERROR accessing price '.h3.text.strip()' in <div class="product-details-price">
# <small class="text-dark">Dealer Price:</small>
# </div>
# Product 8:
#   Name: Under Armour Artemis Hybrid Wms Jacket Rt Xtra Xl 1282685-94
#   SKU: 5017344
# ERROR accessing price '.h3.text.strip()' in <div class="product-details-price">
# <small class="text-dark">Dealer Price:</small>
# </div>
# Product 9:
#   Name: 5.11 Rapid Response LS Shirt Volcanic MD 72430098MD
#   SKU: 5016167
# ERROR accessing price '.h3.text.strip()' in <div class="product-details-price">
# <small class="text-dark">Dealer Price:</small>
# </div>
# Product 10:
#   Name: 5.11 Rapid Response LS Shirt Silver Pine MD 72430800MD
#   SKU: 5016172
# ERROR accessing price '.h3.text.strip()' in <div class="product-details-price">
# <small class="text-dark">Dealer Price:</small>
# </div>
# Product 11:
#   Name: 5.11 Rapid Response LS Shirt Silver Pine SM 72430800SM
#   SKU: 5016171
# ERROR accessing price '.h3.text.strip()' in <div class="product-details-price">
# <small class="text-dark">Dealer Price:</small>
# </div>
# {'category': 'Archery', 'sub_category': 'Archery Accessories (5)', 'url': '/Categories/List/Archery-Accessories'}
# Status Code: 200
# Product 1:
#   Name: .30-06 OUTDOORS BOA Compound Wrist Sling Red
#   SKU: 1114177
# Product 2:
#   Name: .30-06 OUTDOORS BOA Compound Wrist Sling Blue
#   SKU: 1114172
# Product 3:
#   Name: .30-06 OUTDOORS BOA Compound Wrist Sling Teal
#   SKU: 1114178
# Product 4:
#   Name: .30-06 OUTDOORS BOA Compound Wrist Sling Purple
#   SKU: 1114176
# Product 5:
#   Name: Bow Mission Basic Kit w Quiver Sight and Arrow Rest
#   SKU: 1129311
# {'category': 'Archery', 'sub_category': 'Arrows (2)', 'url': '/Categories/List/Arrows'}
# Status Code: 200
# Product 1:
#   Name: New Archery Quikfletch Quikspin In. 6Pk Wht/Yel
#   SKU: 606338
# Product 2:
#   Name: New Archery Quikfletch Twister 2 In. 6Pk  Wht/Org
#   SKU: 606376
# {'category': 'Archery', 'sub_category': 'Bolts (1)', 'url': '/Categories/List/Bolts'}
# Status Code: 200
# Product 1:
#   Name: Bloodsport Hunter 20 in Crossbow Bolt
#   SKU: 1133598
# {'category': 'Archery', 'sub_category': 'Broadheads (21)', 'url': '/Categories/List/Broadheads'}
# Status Code: 200
# Product 1:
#   Name: New Archery Products Practice Bullet Point 0.34375in 125Gr
#   SKU: 1150336
# Product 2:
#   Name: New Archery Products Practice 3D Point 0.34375in 125Gr
#   SKU: 1150345
# Product 3:
#   Name: New Archery Products Practice Bullet Point 0.28in 100Gr
#   SKU: 1150335
# Product 4:
#   Name: New Archery Products Practice Bullet Point 0.34375in 100Gr
#   SKU: 1150334
# Product 5:
#   Name: New Archery Products Quikfletch 2in Twister Blk Tube WOO 6Pk
#   SKU: 1150341
# Product 6:
#   Name: New Archery Products Killzone 125 2 Trophy Tip - 3 Pack
#   SKU: 1108449
# Product 7:
#   Name: NAP Spitfire Maxx 100gr Broadhead w/Trophy Tip 3-blade 3 pk
#   SKU: 1000539
# Product 8:
#   Name: New Archery Products Quikfletch Hellfire 3in WYY 6 Pack
#   SKU: 1150340
# Product 9:
#   Name: New Archery Products Spitfire XXX 100 Gr X Bow 3 Pack
#   SKU: 1125908
# Product 10:
#   Name: New Archery Products Killzone 100 2 Cut on Contact -3 pack
#   SKU: 1108446
# Product 11:
#   Name: New Archery Products Practice 3D Point 0.34375 100Gr
#   SKU: 1150346
# Product 12:
#   Name: New Archery Broadhead-Thunderhead-5 Pk-125Gr
#   SKU: 076473
# Product 13:
#   Name: New Archery Products Practice Bullet Point 0.3125in 100Gr
#   SKU: 1150333
# Product 14:
#   Name: New Archery Products Hellrazor 125 Broadhead - 3 Pack
#   SKU: 1108452
# Product 15:
#   Name: New Archery Crossbow Thunderhead 100Gr 5 Pack
#   SKU: 606949
# Product 16:
#   Name: Bloodsport Gravedigger Extreme Chisel Tip 100G
#   SKU: 1133596
# Product 17:
#   Name: Bloodsport Gravedigger Extreme Cut-On-Contact 100G
#   SKU: 1133597
# Product 18:
#   Name: Bloodsport Night Fury Extreme
#   SKU: 1133595
# Product 19:
#   Name: Bloodsport Gravedigger Cut-On-Contact 125G
#   SKU: 1133591
# Product 20:
#   Name: Bloodsport Nitefall 100G
#   SKU: 1133594
# Product 21:
#   Name: New Archery Crossbow Spitfire Broadhead 125Gr 3Pk
#   SKU: 606970
# {'category': 'Archery', 'sub_category': 'Releases (1)', 'url': '/Categories/List/Releases'}
# Status Code: 200
# Product 1:
#   Name: Cobra Carbon Launcher
#   SKU: 074942
# {'category': 'Archery', 'sub_category': 'Stabilizers (1)', 'url': '/Categories/List/Stabilizers'}
# Status Code: 200
# Product 1:
#   Name: NAP Apache Predator LED Stabilizer
#   SKU: 1000547
# {'category': 'Camping and Outdoor', 'sub_category': 'Appliances and Electronics (6)', 'url': '/Categories/List/Appliances-and-Electronics'}
# Status Code: 200
# Product 1:
#   Name: Cauldryn DC Power Base
#   SKU: 1121427
# Product 2:
#   Name: Cauldryn Digital Heating Base
#   SKU: 1121544
# Product 3:
#   Name: Cauldryn Blend Bottle
#   SKU: 1121491
# Product 4:
#   Name: Cauldryn Coffee Lid
#   SKU: 1121492
# Product 5:
#   Name: Cauldryn Percolator Filters 20 Pack
#   SKU: 1126472
# Product 6:
#   Name: Top Dawg Commercial Heavy Duty Wireless Rear View Camera
#   SKU: 4007005
# {'category': 'Camping and Outdoor', 'sub_category': 'Camping and Outdoor Accessories (3)', 'url': '/Categories/List/Camping-and-Outdoor-Accessories'}
# Status Code: 200
# Product 1:
#   Name: SP Gadgets Remote Pole 39 in. 53021
#   SKU: 5017163
# ERROR accessing price '.h3.text.strip()' in <div class="product-details-price">
# <small class="text-dark">Dealer Price:</small>
# </div>
# Product 2:
#   Name: SP Gadgets Aqua Bundle 53090
#   SKU: 5017162
# ERROR accessing price '.h3.text.strip()' in <div class="product-details-price">
# <small class="text-dark">Dealer Price:</small>
# </div>
# Product 3:
#   Name: Edelweiss Lucy 190 Lumen Lantern VLUCY.1
#   SKU: 5016545
# ERROR accessing price '.h3.text.strip()' in <div class="product-details-price">
# <small class="text-dark">Dealer Price:</small>
# </div>
# {'category': 'Camping and Outdoor', 'sub_category': 'First Aid (5)', 'url': '/Categories/List/First-Aid'}
# Status Code: 200
# Product 1:
#   Name: PROtect Kits 30 pc PPE Kit
#   SKU: 1126812
# Product 2:
#   Name: Tick Twister Blister Pack-12 Pack
#   SKU: 1136802
# Product 3:
#   Name: Tick Twister Clipbox-12 Pack
#   SKU: 1136801
# Product 4:
#   Name: Tick Twister Smartick Blister-Special Hunter-12 Pack
#   SKU: 1136803
# Product 5:
#   Name: Adventure Medical Kits First Aid 32 oz Kit
#   SKU: 1130804
# {'category': 'Camping and Outdoor', 'sub_category': 'Food and Survival (3)', 'url': '/Categories/List/Food-and-Survival'}
# Status Code: 200
# Product 1:
#   Name: Pocket Guide to Animal Tracks
#   SKU: 1150379
# Product 2:
#   Name: SOL Flat Pack Bowls and Strainer Set
#   SKU: 1133300
# Product 3:
#   Name: ReadyWise Simple Kitchen Peaches 6Pk
#   SKU: 1131983
# {'category': 'Camping and Outdoor', 'sub_category': 'Hydration and Water Storage (1)', 'url': '/Categories/List/Hydration-and-Water-Storage'}
# Status Code: 200
# Product 1:
#   Name: RapidPure Purification Straw
#   SKU: 1133293
# {'category': 'Camping and Outdoor', 'sub_category': 'Shovels (1)', 'url': '/Categories/List/Shovels'}
# Status Code: 200
# Product 1:
#   Name: SOG Entrenching Tool
#   SKU: 993296
# {'category': 'Camping and Outdoor', 'sub_category': 'Sleeping Bags (2)', 'url': '/Categories/List/Sleeping-Bags'}
# Status Code: 200
# Product 1:
#   Name: PahaQue Universal Hammock Rainfly for Single Hammock
#   SKU: 1121512
# Product 2:
#   Name: Snugpak Basecamp OPS Navigator SQ Olive LH Zip
#   SKU: 4010530
# ERRROR accessing stock 'span.contents[2].text.strip()' in <div class="product-details-available">
# <span class="text-danger"><b>Available:</b> 0</span>
# </div>
# {'category': 'Camping and Outdoor', 'sub_category': 'Tents (2)', 'url': '/Categories/List/Tents'}
# Status Code: 200
# Product 1:
#   Name: PahaQue Green Mountain 5XD Footprint
#   SKU: 1121509
# Product 2:
#   Name: Coleman Skyshade Beach Shade Small Caribbean
#   SKU: 1150205
# {'category': 'Fishing', 'sub_category': 'Fishing Accessories (2)', 'url': '/Categories/List/Fishing-Accessories'}
# Status Code: 200
# Product 1:
#   Name: Eagle Claw Fresh Water Kit Lead Alternative Weights
#   SKU: 5001708
# Product 2:
#   Name: Cuda 5in Titanium Bonded Braid Shears
#   SKU: 4016308
# ERRROR accessing stock 'span.contents[2].text.strip()' in <div class="product-details-available">
# <span class="text-danger"><b>Available:</b> 0</span>
# </div>
# {'category': 'Fishing', 'sub_category': 'Fly Fishing (1)', 'url': '/Categories/List/Fly-Fishing'}
# Status Code: 200
# Product 1:
#   Name: Scientific Anglers Vest Pack Assortment
#   SKU: 835307
# {'category': 'Fishing', 'sub_category': 'Knives and Tools (1)', 'url': '/Categories/List/Knives-and-Tools'}
# Status Code: 200
# Product 1:
#   Name: Cuda 3 Inch Titanium Bonded Micro Scissors
#   SKU: 3016265
# {'category': 'Fishing', 'sub_category': 'Line, Braid (2)', 'url': '/Categories/List/Line-Braid'}
# Status Code: 200
# Product 1:
#   Name: Daiwa J-Braid X4 Filler Spool 80lb Multi-Color 300 Yds
#   SKU: 1132035
# Product 2:
#   Name: Daiwa J-Braid X4 Filler Spool 65lb Multi-Color 300 Yds
#   SKU: 1132034
# {'category': 'Fishing', 'sub_category': 'Lures, Hard Bait (2)', 'url': '/Categories/List/Lures-Hard-Bait'}
# Status Code: 200
# Product 1:
#   Name: Strike King KVD Elite Jerkbait 300 Pro Shizzle
#   SKU: 1136698
# Product 2:
#   Name: Strike King KVD Elite Jerkbait 300 Pro TN Shad 2.0
#   SKU: 1136700
# {'category': 'Fishing', 'sub_category': 'Reels, Baitcast (2)', 'url': '/Categories/List/Reels-Baitcast'}
# Status Code: 200
# Product 1:
#   Name: Savage Gear SG 6 BC 100 LH 6.6 5+1BB
#   SKU: 1133490
# Product 2:
#   Name: Savage Gear SG 6 BC 100 LH 8.1 5+1BB
#   SKU: 1133492
# {'category': 'Fishing', 'sub_category': 'Reels, Spinning (1)', 'url': '/Categories/List/Reels-Spinning'}
# Status Code: 200
# Product 1:
#   Name: Shimano Baitrunner Spinning Reel 4000 OC BTR4000OC
#   SKU: 161992
# {'category': 'Fishing', 'sub_category': 'Rods (2)', 'url': '/Categories/List/Rods'}
# Status Code: 200
# Product 1:
#   Name: Douglas LRS C684F Casting Rod 1 Piece Blue
#   SKU: 1129166
# Product 2:
#   Name: Douglas LRS C685XF Casting Rod 1 Piece Blue
#   SKU: 1129167
# {'category': 'Fishing', 'sub_category': 'Terminal (1)', 'url': '/Categories/List/Terminal'}
# Status Code: 200
# Product 1:
#   Name: Danielson 2300SP-BLK B-BEARING SWVL
#   SKU: 764209
# {'category': 'Gifts and Novelty', 'sub_category': 'Gifts (9)', 'url': '/Categories/List/Gifts'}
# Status Code: 200
# Product 1:
#   Name: River's Edge 24" X 16" Led Wall Art - Whitetail Deer 1812
#   SKU: 5017054
# ERROR accessing price '.h3.text.strip()' in <div class="product-details-price">
# <small class="text-dark">Dealer Price:</small>
# </div>
# Product 2:
#   Name: ATN Authorized Dealer Window Sticker
#   SKU: ATNDLRSTCKR
# ERROR accessing price '.h3.text.strip()' in <div class="product-details-price">
# <small class="text-dark">Dealer Price:</small>
# </div>
# Product 3:
#   Name: ATN Store Banner
#   SKU: ATNSTRBANR
# ERROR accessing price '.h3.text.strip()' in <div class="product-details-price">
# <small class="text-dark">Dealer Price:</small>
# </div>
# Product 4:
#   Name: Rivers Edge Welcome Canoe Hanging Metal Sign
#   SKU: 5017056
# ERROR accessing price '.h3.text.strip()' in <div class="product-details-price">
# <small class="text-dark">Dealer Price:</small>
# </div>
# Product 5:
#   Name: ATN Acrylic 8.5x11 in Sign Holder
#   SKU: ATNSGNHLDR
# ERROR accessing price '.h3.text.strip()' in <div class="product-details-price">
# <small class="text-dark">Dealer Price:</small>
# </div>
# Product 6:
#   Name: ATN Shelf Product Holder
#   SKU: ATNPRDCTHLDR
# ERROR accessing price '.h3.text.strip()' in <div class="product-details-price">
# <small class="text-dark">Dealer Price:</small>
# </div>
# Product 7:
#   Name: Mako Mojo Replaceable Deco Cavalier - Medieval Helmet FDE
#   SKU: 1112246
# Product 8:
#   Name: Gerber Barbill Wallet Gray
#   SKU: 4018951
# {'category': 'Gifts and Novelty', 'sub_category': 'Hardware (3)', 'url': '/Categories/List/Hardware'}
# Status Code: 200
# Product 1:
#   Name: Dura-Winder Combo - 2 Pack
#   SKU: 1114111
# Product 2:
#   Name: Dura-Winder Combo - 6 Pack
#   SKU: 1114113
# Product 3:
#   Name: Dura-Winder Combo - 4 Pack
#   SKU: 1114112
# {'category': 'Gifts and Novelty', 'sub_category': 'Lighters (1)', 'url': '/Categories/List/Lighters'}
# Status Code: 200
# Product 1:
#   Name: Zippo Red Matte With Zippo Logo 233ZL
#   SKU: 113452
# {'category': 'Golf', 'sub_category': 'Apparel (1)', 'url': '/Categories/List/Apparel'}
# Status Code: 200
# Product 1:
#   Name: Volvik Marvel Golf Hat Spider Man Red
#   SKU: 1133419
# {'category': 'Golf', 'sub_category': 'Bags (52)', 'url': '/Categories/List/Bags'}
# Status Code: 200
# Product 1:
#   Name: Bridgestone NCAA Golf Stand Bag-Georgia
#   SKU: 1150589
# Product 2:
#   Name: Bridgestone NCAA Golf Stand Bag-Iowa
#   SKU: 1150590
# Product 3:
#   Name: Bridgestone NCAA Golf Stand Bag-Michigan
#   SKU: 1150591
# Product 4:
#   Name: Bridgestone NCAA Golf Stand Bag-Ohio State
#   SKU: 1150592
# Product 5:
#   Name: Bridgestone NCAA Golf Stand Bag-Texas
#   SKU: 1150593
# Product 6:
#   Name: Bridgestone NCAA Golf Stand Bag-Wisconsin
#   SKU: 1150588
# Product 7:
#   Name: Callaway Golf Fairway Plus Stand Bag Black
#   SKU: 1150532
# Product 8:
#   Name: Callaway Golf Fairway Plus Stand Bag Navy-Grey
#   SKU: 1150533
# Product 9:
#   Name: Callaway Golf Fairway C Stand Bag Black
#   SKU: 1150537
# Product 10:
#   Name: Callaway 2024 Fairway C Golf Stand Bag Fire White
#   SKU: 1150235
# Product 11:
#   Name: Callaway 2024 ORG 14 Golf Cart Bag White Violet
#   SKU: 1150248
# Product 12:
#   Name: Callaway Golf Chase 14 Cart Bag Black
#   SKU: 1150543
# Product 13:
#   Name: Callaway Golf Chase 14 Cart Bag Navy
#   SKU: 1150544
# Product 14:
#   Name: Callaway Golf Chase 14 Cart Bag Silver Hydrangea
#   SKU: 1150545
# Product 15:
#   Name: Callaway Golf Hyperlite Zero Stand Bag Black
#   SKU: 1150547
# Product 16:
#   Name: Callaway Golf Hyperlite Zero Stand Bag White Orchid Petal
#   SKU: 1150549
# Product 17:
#   Name: Callaway Golf Hyperlite Zero Stand Bag Navy White Red
#   SKU: 1150550
# Product 18:
#   Name: Callaway Golf ORG 14 Cart Bag Black
#   SKU: 1150551
# Product 19:
#   Name: Callaway Golf ORG 14 Cart Bag Navy White Red
#   SKU: 1150552
# Product 20:
#   Name: Callaway Golf ORG 14 Cart Bag Navy
#   SKU: 1150553
# Product 21:
#   Name: Callaway Golf ORG 14 Cart Bag White Cardinal
#   SKU: 1150554
# Product 22:
#   Name: Callaway Golf ORG 14 Cart Bag Silver Orchid Petal
#   SKU: 1150555
# Product 23:
#   Name: Callaway Golf ORG 14 Cart Bag Midnight Hydrangea
#   SKU: 1150556
# Product 24:
#   Name: Callaway Golf ORG 14 Cart Bag Hex Camo White
#   SKU: 1150557
# Product 25:
#   Name: Callaway Golf Fairway Plus Stand Bag Red-White-Navy
#   SKU: 1150534
# {'category': 'Golf', 'sub_category': 'Balls (15)', 'url': '/Categories/List/Balls'}
# Status Code: 200
# Product 1:
#   Name: Bridgestone 2021 e6 White Golf Ball - Dozen
#   SKU: 1129012
# Product 2:
#   Name: Callaway Golf 2023 ERC Soft Triple Track Golf Ball-White
#   SKU: 1137166
# {'category': 'Golf', 'sub_category': 'Clubs (44)', 'url': '/Categories/List/Clubs'}
# Status Code: 200
# Product 1:
#   Name: Strata Plus Mens Golf Package Set 14pc Right Hand
#   SKU: 1113873
# Product 2:
#   Name: Callaway Golf XR Complete Golf Set-RH REG Steel Shaft
#   SKU: 1137185
# Product 3:
#   Name: Callaway XJ Junior Golf Set Level 2 RH White
#   SKU: 1110202
# Product 4:
#   Name: Callaway Golf Womens Strata Ultimate Complete Set
#   SKU: 1150558
# Product 5:
#   Name: Callaway Golf Mens Strata Ultimate Complete Set
#   SKU: 1150559
# Product 6:
#   Name: Callaway Golf Women's REVA Golf Set 11pc with Stand Bag
#   SKU: 1150566
# Product 7:
#   Name: Callaway Golf Women's REVA Golf Set 11pc with Cart Bag
#   SKU: 1150567
# Product 8:
#   Name: Callaway Golf Women's REVA Golf Set 11pc with EGPLNT Cart Bag
#   SKU: 1150568
# Product 9:
#   Name: Callaway Golf XR Complete Set BLK-SLV GR REG
#   SKU: 1150560
# Product 10:
#   Name: Callaway Golf XR Complete Set BLU-SLV GR REG
#   SKU: 1150561
# Product 11:
#   Name: Callaway Golf XR Complete Set BLK-SLV ST REG
#   SKU: 1150562
# Product 12:
#   Name: Callaway Golf XR Complete Set BLU-SLV ST REG
#   SKU: 1150563
# Product 13:
#   Name: Callaway Golf XR Complete Set BLU-SLV ST Stiff
#   SKU: 1150565
# Product 14:
#   Name: Callaway XJ Junior Golf Set Level 2 RH Blue
#   SKU: 1110201
# Product 15:
#   Name: Callaway Golf XR Complete Golf Set RH REG Graphite Shaft
#   SKU: 1137183
# Product 16:
#   Name: Callaway XJ Junior Golf Set Level 3 RH White
#   SKU: 1110206
# Product 17:
#   Name: Callaway Golf XR Complete Set BLK-SLV ST Stiff
#   SKU: 1150564
# Product 18:
#   Name: Tour Edge 2020 Lady Edge Full Set Turquoise Grey White
#   SKU: 1125658
# Product 19:
#   Name: Tour Edge Moda Silk Womens Golf Set-Black-LT Blue-RH-Petite
#   SKU: 1130171
# Product 20:
#   Name: Strata Womens Golf Package Set 11pc Right Hand
#   SKU: 1113869
# Product 21:
#   Name: Tour Edge Golf TE-200 Varsity Complete Set with Bag
#   SKU: 1150570
# Product 22:
#   Name: Tour Edge TE-400 Package Set Regular Graphite
#   SKU: 1150573
# Product 23:
#   Name: Tour Edge TE-400 Package Set Uniflex Steel
#   SKU: 1150574
# Product 24:
#   Name: Callaway XT 10-Piece Teen Golf Set RH
#   SKU: 1110208
# Product 25:
#   Name: Strata Mens Golf Package Set 12pc Right Hand
#   SKU: 1113870
# {'category': 'Hunting', 'sub_category': 'Accessories (2)', 'url': '/Categories/List/Accessories'}
# Status Code: 200
# Product 1:
#   Name: Altus BenchMaster Single Gun Pistol Velcro Hook Rack
#   SKU: 2000374
# Product 2:
#   Name: Altus BenchMaster Two Gun Pistol Magnetic Strip Rack
#   SKU: 2000373
# {'category': 'Hunting', 'sub_category': 'Game Calls (6)', 'url': '/Categories/List/Game-Calls'}
# Status Code: 200
# Product 1:
#   Name: Cass Creek Electronic Ergo Spring Gobbler Call CC-041
#   SKU: 341041
# Product 2:
#   Name: Cass Creek Ergo Deer Call
#   SKU: 1003305
# Product 3:
#   Name: Zink PC-1 Polycarb Goose Call Shadow Grass Blade
#   SKU: 1133738
# Product 4:
#   Name: Zink PC-1 Polycarb Goose Call Gunsmoke
#   SKU: 1133768
# Product 5:
#   Name: Zink Call Of Death Polycarb Goose Call Custom Hunter
#   SKU: 1133760
# Product 6:
#   Name: Extreme Dimension iHunt by Ruger Bluetooth Game Call
#   SKU: 1005302
# {'category': 'Hunting', 'sub_category': 'Game Cameras (8)', 'url': '/Categories/List/Game-Cameras'}
# Status Code: 200
# Product 1:
#   Name: Stealth Cam Fusion Max  36Mp  2 Pack
#   SKU: 1150348
# Product 2:
#   Name: Stealth Cam Deceptor Max 40MP
#   SKU: 1150350
# Product 3:
#   Name: Stealth Cam FusionMax  36Mp
#   SKU: 1150347
# Product 4:
#   Name: Stealth Cam 3000 Mah Fieldmax External Ex Solar Battery Pack
#   SKU: 1150354
# Product 5:
#   Name: Stealth Cam Deceptor Max 40MP 2 Pack
#   SKU: 1150351
# Product 6:
#   Name: Stealth Cam DS4K Transmit Cellular 48MP w 32GB SD Card
#   SKU: 1150353
# Product 7:
#   Name: Stealth Cam Revolver 36Mp  360 Degrees Cellular Trail Camera
#   SKU: 1150349
# Product 8:
#   Name: Stealth Cam Revolver Pro 40MP 360 Degree Cellular Trail Cam
#   SKU: 1150352
# {'category': 'Hunting', 'sub_category': 'Game Cameras and Accessories (1)', 'url': '/Categories/List/Game-Cameras-and-Accessories'}
# Status Code: 200
# Product 1:
#   Name: Stealth Cam Small Security Box QS QV PX
#   SKU: 1125710
# ERRROR accessing stock 'span.contents[2].text.strip()' in <div class="product-details-available">
# <span class="text-danger"><b>Available:</b> 0</span>
# </div>
# {'category': 'Hunting', 'sub_category': 'Gun Cases (1)', 'url': '/Categories/List/Gun-Cases'}
# Status Code: 200
# Product 1:
#   Name: Vism Rifle Case 36inL x 13inH-Digital Camo ACU
#   SKU: 813394
# {'category': 'Hunting', 'sub_category': 'Seats (1)', 'url': '/Categories/List/Seats'}
# Status Code: 200
# Product 1:
#   Name: BOG Ultralite DeathGrip w Fluid Head
#   SKU: 1129388
# {'category': 'Hunting', 'sub_category': 'Targets (1)', 'url': '/Categories/List/Targets'}
# Status Code: 200
# Product 1:
#   Name: Caldwell 8in Sight-In Target 25 Sheets
#   SKU: 1132828
# Product 2:
#   Name: Birchwood Casey Eze-Scorer 23in X 35in Mule Deer-2 Pack
#   SKU: 1150328
# {'category': 'Knives and Tools', 'sub_category': 'Knives - Fixed Blade (3)', 'url': '/Categories/List/Knives-Fixed-Blade'}
# Status Code: 200
# Product 1:
#   Name: Cold Steel Tanto Lite Fixed 6 in Blade Kray-Ex Handle
#   SKU: 4019499
# Product 2:
#   Name: SOG Seal Pup Kydex Sheath
#   SKU: 991483
# Product 3:
#   Name: Total Gear Maxam Ram Horn Hunter Fixed Blade Knive w/ Sheath
#   SKU: 5017199
# ERROR accessing price '.h3.text.strip()' in <div class="product-details-price">
# <small class="text-dark">Dealer Price:</small>
# </div>
# {'category': 'Knives and Tools', 'sub_category': 'Knives - Folding (8)', 'url': '/Categories/List/Knives-Folding'}
# Status Code: 200
# Product 1:
#   Name: MTech Folder 3.25 in Blade Wood-Stainless Steel Handle
#   SKU: 4019046
# Product 2:
#   Name: Cold Steel Micro Recon 1 Tanto Pt Folder 2in Blade G10 Hndl
#   SKU: 4019625
# Product 3:
#   Name: Cold Steel Rajah III Folder 3.5 in Plain GFN Handle
#   SKU: 4016998
# Product 4:
#   Name: Cold Steel Luzon Folder 4.0 in Plain Black GFN Handle
#   SKU: 4016034
# Product 5:
#   Name: Cold Steel Pocket Bushman
#   SKU: 007364
# Product 6:
#   Name: Cold Steel Recon 1 Folder 4.0 in Blk Spear Point Plain G-10
#   SKU: 4016586
# Product 7:
#   Name: Schrade Manilla Folder
#   SKU: 1133333
# Product 8:
#   Name: Schrade Torsion
#   SKU: 1133356
# {'category': 'Knives and Tools', 'sub_category': 'Knives - Machetes (1)', 'url': '/Categories/List/Knives-Machetes'}
# Status Code: 200
# Product 1:
#   Name: SOG SOGfari Kukri Machete
#   SKU: 4000383
# {'category': 'Knives and Tools', 'sub_category': 'Knives - Throwing (2)', 'url': '/Categories/List/Knives-Throwing'}
# Status Code: 200
# Product 1:
#   Name: Cold Steel Sure Flight Thrower 12.00 in Overall Length
#   SKU: 4000311
# Product 2:
#   Name: S and W Bullseye Throwers 8.00 in Overall Length Set of 6
#   SKU: 4010494
# {'category': 'Knives and Tools', 'sub_category': 'Knives - Training (2)', 'url': '/Categories/List/Knives-Training'}
# Status Code: 200
# Product 1:
#   Name: Cold Steel Leatherneck Special Forces Trainer 92R39LSF
#   SKU: 009412
# Product 2:
#   Name: Cold Steel Military Classic Trainer 6.75 in Blade
#   SKU: 4017892
# {'category': 'Knives and Tools', 'sub_category': 'Multi-Tools (3)', 'url': '/Categories/List/MultiTools'}
# Status Code: 200
# Product 1:
#   Name: SOG Powerlitre Black
#   SKU: 1133824
# Product 2:
#   Name: Gerber Multi-Plier 600 with 15 Tools
#   SKU: 9000420
# Product 3:
#   Name: Gerber Prybrid Utility Green
#   SKU: 1126830
# {'category': 'Lights', 'sub_category': 'Accessories - Lights (1)', 'url': '/Categories/List/Accessories-Lights'}
# Status Code: 200
# Product 1:
#   Name: Nightstick Clip-On Magnetic Base - 5566-68
#   SKU: 4017339
# {'category': 'Lights', 'sub_category': 'Batteries and Chargers (5)', 'url': '/Categories/List/Batteries-and-Chargers'}
# Status Code: 200
# Product 1:
#   Name: ASP Retractable Plus Yellow
#   SKU: 1129566
# Product 2:
#   Name: ASP Charge Bank
#   SKU: 1129567
# Product 3:
#   Name: Energizer CR2 Battery 2pk EL1CR2BP2
#   SKU: 4000302
# Product 4:
#   Name: NITECORE 18650 Rechargeable Battery 3400mAh
#   SKU: 9004637
# Product 5:
#   Name: Deltran BT Plus 1 Bank 12 Volt
#   SKU: 001280
# Product 6:
#   Name: SureFire Sf123A Bulk Box 400 Cells
#   SKU: 1127787
# {'category': 'Lights', 'sub_category': 'Handheld Lights (2)', 'url': '/Categories/List/Handheld-Lights'}
# Status Code: 200
# Product 1:
#   Name: Leapers UTG Libre Intensity Adjust LED 700 Lumen Flashlight
#   SKU: 1124732
# Product 2:
#   Name: SOL Venture Light 3000 Recharge with Power Bank
#   SKU: 1133309
# {'category': 'Marine and Water Sports', 'sub_category': 'Batteries and Chargers (1)', 'url': '/Categories/List/Batteries-and-Chargers'}
# Status Code: 200
# Product 1:
#   Name: ASP Retractable Plus Yellow
#   SKU: 1129566
# Product 2:
#   Name: ASP Charge Bank
#   SKU: 1129567
# Product 3:
#   Name: Energizer CR2 Battery 2pk EL1CR2BP2
#   SKU: 4000302
# Product 4:
#   Name: NITECORE 18650 Rechargeable Battery 3400mAh
#   SKU: 9004637
# Product 5:
#   Name: Deltran BT Plus 1 Bank 12 Volt
#   SKU: 001280
# Product 6:
#   Name: SureFire Sf123A Bulk Box 400 Cells
#   SKU: 1127787
# {'category': 'Marine and Water Sports', 'sub_category': 'Marine Accessories (1)', 'url': '/Categories/List/Marine-Accessories'}
# Status Code: 200
# Product 1:
#   Name: Scotty Oar Collars Bulk no package
#   SKU: 621010
# {'category': 'Marine and Water Sports', 'sub_category': 'Marine And Water Sports Accesso (1)', 'url': '/Categories/List/Marine-And-Water-Sports-Accesso'}
# Status Code: 200
# Product 1:
#   Name: Davis Instruments Fender Friend Center Tube Black
#   SKU: 1131350
# {'category': 'Nightvision and Thermal', 'sub_category': 'Riflescopes (22)', 'url': '/Categories/List/Riflescopes'}
# Status Code: 200
# Product 1:
#   Name: ATN X-Sight LTV 3-9x Day Night Hunting Rifle Scope
#   SKU: 1127631
# Product 2:
#   Name: ATN X-Sight 5 LRF 3-15x UHD Smart Day Night Rifle Scope
#   SKU: 1137330
# Product 3:
#   Name: ATN X-Sight 5 3-15x UHD Smart Day Night Hunting Rifle Scope
#   SKU: 1137328
# Product 4:
#   Name: ATN X-Sight LTV 5-15x Day Night Hunting Rifle Scope
#   SKU: 1127632
# Product 5:
#   Name: ATN X-Sight 5 LRF 5-25x UHD Smart Day Night Rifle Scope
#   SKU: 1137331
# Product 6:
#   Name: ATN X-Sight 5 5-25x UHD Smart Day Night Hunting Rifle Scope
#   SKU: 1137329
# Product 7:
#   Name: ATN ODIN LT 640 1-4x 19mm Compact Thermal Viewer
#   SKU: 1137352
# Product 8:
#   Name: ATN ODIN LT 640 2-8x 25mm Compact Thermal Viewer
#   SKU: 1137353
# Product 9:
#   Name: ATN ODIN LT 640 3-12x 35mm Compact Thermal Viewer
#   SKU: 1137354
# Product 10:
#   Name: ATN Thor 5 3-12x 320x240 12 mic Smart HD Thermal Rifle Scope
#   SKU: 1137332
# Product 11:
#   Name: ATN Thor 5 LRF 3-12x 320x240 12 mic Smart HD Thermal Scope
#   SKU: 1137342
# Product 12:
#   Name: ATN Thor 5 LRF 4-16x 320x240 12 mic Smart HD Thermal Scope
#   SKU: 1137343
# Product 13:
#   Name: ATN Thor 5 5-20x 320x240 12 mic Smart HD Thermal Rifle Scope
#   SKU: 1137334
# Product 14:
#   Name: ATN Thor 5 LRF 5-20x 320x240 12 mic Smart HD Thermal Scope
#   SKU: 1137344
# Product 15:
#   Name: ATN Thor 5 2-16x 640x480 12 mic Smart HD Thermal Rifle Scope
#   SKU: 1137335
# Product 16:
#   Name: ATN Thor 5 LRF 2-16x 640x480 12 mic Smart HD Thermal Scope
#   SKU: 1137345
# Product 17:
#   Name: ATN Thor 5 3-24x 640x480 12 mic Smart HD Thermal Rifle Scope
#   SKU: 1137336
# Product 18:
#   Name: ATN Thor 5 LRF 3-24x 640x480 12 mic Smart HD Thermal Scope
#   SKU: 1137346
# Product 19:
#   Name: ATN Thor 5 4-32x 640x480 12 mic Smart HD Thermal Rifle Scope
#   SKU: 1137337
# Product 20:
#   Name: ATN Thor 5 LRF 4-32x 640x480 12 mic Smart HD Thermal Scope
#   SKU: 1137347
# Product 21:
#   Name: ATN Thor 5 5-40x 640x480 12 mic Smart HD Thermal Rifle Scope
#   SKU: 1137338
# Product 22:
#   Name: ATN Thor 5 LRF 5-40x 640x480 12 mic Smart HD Thermal Scope
#   SKU: 1137348
# {'category': 'Optics and Sights', 'sub_category': 'Binoculars and Monoculars (12)', 'url': '/Categories/List/Binoculars-and-Monoculars'}
# Status Code: 200
# Product 1:
#   Name: ATN BlazeSeeker-207 Therm Image Mono 256x192 1-8.8X 12 Micro
#   SKU: 1150479
# Product 2:
#   Name: ATN BlazeSeeker-210 Thermal Imaging Mono 256x192 1.5-12x 12
#   SKU: 1150478
# Product 3:
#   Name: ATN Binox 4T 384 2-8x Thermal Binocular w Laser range finder
#   SKU: 1125014
# Product 4:
#   Name: ATN Binox 4T 384 4.5-18x Thermal Binocular Laser RangeFinder
#   SKU: 1125015
# Product 5:
#   Name: ATN Binox 4T 640 1-10x Thermal Binocular w Laser RangeFinder
#   SKU: 1125016
# Product 6:
#   Name: ATN Binox 4T 640 1.5-15x Thermal Binocular Laser RangeFinder
#   SKU: 1125017
# Product 7:
#   Name: ATN Binox 4T 640 2.5-25x Thermal Binocular Laser RangeFinder
#   SKU: 1125018
# Product 8:
#   Name: ATN BlazeTrek-325 Thermal Imaging Monocular 12Micron 384x288
#   SKU: 1150482
# Product 9:
#   Name: ATN BlazeTrek-619 Thermal Imaging Monocular 12Micron 640x512
#   SKU: 1150481
# Product 10:
#   Name: ATN BlazeTrek-625 Thermal Imaging Monocular 12Micron 640x512
#   SKU: 1150480
# Product 11:
#   Name: ATN ODIN LT 320 2-4X Compact Therml Viewer
#   SKU: 1133425
# Product 12:
#   Name: ATN ODIN LT 320 4-8X Compact Therml Viewer
#   SKU: 1133427
# {'category': 'Optics and Sights', 'sub_category': 'Laser (1)', 'url': '/Categories/List/Laser'}
# Status Code: 200
# Product 1:
#   Name: Crimson Trace Laserguard Hellcat Red
#   SKU: 1129454
# {'category': 'Optics and Sights', 'sub_category': 'Mounts and Rings (2)', 'url': '/Categories/List/Mounts-and-Rings'}
# Status Code: 200
# Product 1:
#   Name: B-Square SAF-S30C AR-15 Ring Mounts For Flat Top Receivers
#   SKU: 4001273
# Product 2:
#   Name: Leapers UTG PRO 1in 2pc Medium Profile P.O.I Picatinny Rings
#   SKU: 1124701
# {'category': 'Optics and Sights', 'sub_category': 'Optics and Sight Accessories (2)', 'url': '/Categories/List/Optics-and-Sight-Accessories'}
# Status Code: 200
# Product 1:
#   Name: Bino Dock T Bag Desert Tan
#   SKU: 4019376
# Product 2:
#   Name: Vism Universal Pistol Front and Rear Sight Tool
#   SKU: 1122000
# {'category': 'Optics and Sights', 'sub_category': 'Rangefinders (1)', 'url': '/Categories/List/Rangefinders'}
# Status Code: 200
# Product 1:
#   Name: ATN Binox 4T 384-1.25-5x Thermal Binocular Laser RangeFinder
#   SKU: 1125013
# {'category': 'Optics and Sights', 'sub_category': 'Scopes (2)', 'url': '/Categories/List/Scopes'}
# Status Code: 200
# Product 1:
#   Name: NcSTAR SPB2530B 2.5X30 Pistol Scope Blue Lens Ring
#   SKU: 1150491
# Product 2:
#   Name: NcStar Pistolero 2-7X32 Pistol Scope
#   SKU: 811086
# ERRROR accessing stock 'span.contents[2].text.strip()' in <div class="product-details-available">
# <span class="text-danger"><b>Available:</b> 0</span>
# </div>
# {'category': 'Optics and Sights', 'sub_category': 'Scopes, Long Gun (2)', 'url': '/Categories/List/Scopes-Long-Gun'}
# Status Code: 200
# Product 1:
#   Name: Night Fision Tritium AR15 Front Sight Post Orange Ring
#   SKU: 1135148
# Product 2:
#   Name: Night Fision AR15 Front Sight Post Magpul MBUS Pro Yel Ring
#   SKU: 1135149
# {'category': 'Optics and Sights', 'sub_category': 'Sights (3)', 'url': '/Categories/List/Sights'}
# Status Code: 200
# Product 1:
#   Name: TruGlo Tritium Pro Glock 42 43 MOS Set White
#   SKU: 1135640
# Product 2:
#   Name: TruGlo Bow Jack LW Folding Bow Stand Mini Wide Black Red
#   SKU: 1150357
# Product 3:
#   Name: TruGlo TFX Rugar SR Set Pro ORN Handgun Sight
#   SKU: 1007616
# Product 4:
#   Name: TruGlo Tritium Pro Glock MOS Low Set Orange
#   SKU: 1150359
# Product 5:
#   Name: Troy Fixed M4 Front Sight-Black
#   SKU: 1134556
# Product 6:
#   Name: TruGlo Tritium Pro Glock Mos Hi Set Orange
#   SKU: 1150358
# Product 7:
#   Name: TruGlo TFX Pro CZ P10 Set
#   SKU: 1150355
# ERRROR accessing stock 'span.contents[2].text.strip()' in <div class="product-details-available">
# <span class="text-danger"><b>Available:</b> 0</span>
# </div>
# Product 8:
#   Name: TruGlo TFX Steyr Set Pro ORN Handgun Sight
#   SKU: 1007620
# ERRROR accessing stock 'span.contents[2].text.strip()' in <div class="product-details-available">
# <span class="text-danger"><b>Available:</b> 0</span>
# </div>
# {'category': 'Optics and Sights', 'sub_category': 'Sights, Pistol (6)', 'url': '/Categories/List/Sights-Pistol'}
# Status Code: 200
# Product 1:
#   Name: TruGlo TFX Pro Tritium Fiber Handgun Sight - Walther CCP ORN
#   SKU: 1108727
# Product 2:
#   Name: TruGlo Tritium Pro Handgun Sight - Glock Hi MOS
#   SKU: 1108761
# Product 3:
#   Name: Night Fision Optics Ruger Max 9 Yellow Front Ring Sq Rear
#   SKU: 1135133
# Product 4:
#   Name: TruGlo Tritium Pro Handgun Sight - Glock Low MOS
#   SKU: 1108760
# Product 5:
#   Name: Vism Compact Pistol Green Laser w Strobe-Black
#   SKU: 1121990
# Product 6:
#   Name: Meprolight Sprgfld Tru-Dot Nght Sght-XD .45 ACP Fixed Set
#   SKU: 5002019
# {'category': 'Optics and Sights', 'sub_category': 'Sights, Reflex and Red Dot (1)', 'url': '/Categories/List/Sights-Reflex-and-Red-Dot'}
# Status Code: 200
# Product 1:
#   Name: NcSTAR Flipdot Pro Red Dot-Black
#   SKU: 1150504
# {'category': 'Public Safety and LE', 'sub_category': 'Body Armor and Protection (24)', 'url': '/Categories/List/Body-Armor-and-Protection'}
# Status Code: 200
# Product 1:
#   Name: PahaQue Personal Protective Facemask Camo Black-Cotton
#   SKU: 1127392
# Product 2:
#   Name: PahaQue Personal Protective Facemask Pink
#   SKU: 1126467
# Product 3:
#   Name: PahaQue Personal Protective Facemask Black
#   SKU: 1126465
# Product 4:
#   Name: PahaQue Personal Protective Facemask Camo Black-Lycra
#   SKU: 1126466
# Product 5:
#   Name: Seirus Evo Arc Masque Black Lg
#   SKU: 1128975
# Product 6:
#   Name: VISM Unisex Adult Tactical Apron Digital Camo-OSFM
#   SKU: 1150495
# Product 7:
#   Name: NcSTAR CTV2916WC Tactical Vest-Woodland Camo-M-XL
#   SKU: 1150494
# Product 8:
#   Name: Vism Tactical Vest Digital Camo-XS-Sm
#   SKU: 1122551
# Product 9:
#   Name: NcSTAR Childrens Vest-Green
#   SKU: 1150492
# Product 10:
#   Name: VISM CTVC2916WC Tactical Vest-Small-Woodland Camo
#   SKU: 1150493
# Product 11:
#   Name: Seirus Evo Arc Masque Black Sm
#   SKU: 1128973
# Product 12:
#   Name: Vism Lvl 4 Ceramic PE Ballist Plate 6x6in Curved SidePlate
#   SKU: 1134760
# Product 13:
#   Name: Vism 3A SRT Ceramic Ballistic Plate 6x6in Curved SidePlate
#   SKU: 1134759
# Product 14:
#   Name: Vism Ballistic Shield 3A 12inHx24inW Pistol
#   SKU: 1134753
# Product 15:
#   Name: Vism Concealed Carrier Vest w 2 3A Ball Panels-White 2XL
#   SKU: 1134743
# Product 16:
#   Name: Vism Concealed Carrier Vest w 2 3A Ballist Panels-White Sm
#   SKU: 1134738
# Product 17:
#   Name: Vism Outer Carrier Vest w 4 3A Ballistic Panels-Black Med
#   SKU: 1134732
# Product 18:
#   Name: Vism Outer Carrier Vest w 4 3A Ballistic Panels-Black Sm
#   SKU: 1134731
# Product 19:
#   Name: Vism Concealed Carrier Vest w 2 3A Ballist Panels-Black Lg
#   SKU: 1134747
# Product 20:
#   Name: Vism Concealed Carrier Vest w 2 3A Ballist Panels-Black Md
#   SKU: 1134746
# Product 21:
#   Name: Vism Concealed Carrier Vest w 2 3A Ballist Panels-Black Sm
#   SKU: 1134745
# Product 22:
#   Name: Vism Outer Carrier Vest w 4 3A Ballistic Panels-Black Lg
#   SKU: 1134733
# Product 23:
#   Name: Vism Outer Carrier Vest w 4 3A Ballistic Panels-Black XL
#   SKU: 1134730
# Product 24:
#   Name: Vism Tactical Vest Black-XS-Sm
#   SKU: 1122550
# ERRROR accessing stock 'span.contents[2].text.strip()' in <div class="product-details-available">
# <span class="text-danger"><b>Available:</b> 0</span>
# </div>
# {'category': 'Public Safety and LE', 'sub_category': 'Hearing Protection (3)', 'url': '/Categories/List/Hearing-Protection'}
# Status Code: 200
# Product 1:
#   Name: Walkers Infant Passive Muff Baby Blue
#   SKU: 1112832
# Product 2:
#   Name: Walkers Infant Passive Muff Pink
#   SKU: 1112833
# Product 3:
#   Name: Pro Ears ReVO Electronic Ear Muffs - NRR 25 Zombie
#   SKU: 1109838
# {'category': 'Public Safety and LE', 'sub_category': 'Personal Defense (1)', 'url': '/Categories/List/Personal-Defense'}
# Status Code: 200
# Product 1:
#   Name: ASP LockWrite Pen Key Twist Gold Accents
#   SKU: 1129541
# {'category': 'Public Safety and LE', 'sub_category': 'Pouches (1)', 'url': '/Categories/List/Pouches'}
# Status Code: 200
# Product 1:
#   Name: Maxpedition FRP First Response Pouch Black
#   SKU: 9006256
# {'category': 'Shooting', 'sub_category': 'Accessories and Parts (14)', 'url': '/Categories/List/Accessories-and-Parts'}
# Status Code: 200
# Product 1:
#   Name: Competition Electronics ProTimer Shot Timer
#   SKU: 1134508
# Product 2:
#   Name: Troy Hand Stop Assembly 2.2 in-Grey
#   SKU: 1134575
# Product 3:
#   Name: Troy Semi Auto Direct Thread Ambi Safety Selector Assembly
#   SKU: 1134589
# Product 4:
#   Name: Competition Electronics Pocket Pro Timer
#   SKU: 528003
# Product 5:
#   Name: Vism MOS 500 590 Handguard Tan
#   SKU: 1131875
# Product 6:
#   Name: M and P Accessories AR-15 Complete Upper Parts Kit ITAR
#   SKU: 1127242
# Product 7:
#   Name: Hogue AR15 M16 Free Float Forend with Grey Rubber Gripping
#   SKU: 1126918
# Product 8:
#   Name: Hogue AR15 M16 Rifle Len FreeFloat Forend wOM Gripping Grey
#   SKU: 1126928
# Product 9:
#   Name: Leapers UTG PRO M-LOK AR15 15in SuperSlim Free Float H Guard
#   SKU: 1124683
# Product 10:
#   Name: ProMag AR-15 M-16 Lower Receiver Mag Well Vise Block-Black
#   SKU: 1125226
# Product 11:
#   Name: Troy Ambidextrous Extended Charging Handle 5.56
#   SKU: 1134588
# Product 12:
#   Name: Troy Hand Stop Assembly 2.2 in-Black
#   SKU: 1134573
# Product 13:
#   Name: Vism Rem 870 PG Stock Adapt Tan
#   SKU: 1131884
# Product 14:
#   Name: Competition Electronics ProTimerBT Shot Timer
#   SKU: 1132127
# ERRROR accessing stock 'span.contents[2].text.strip()' in <div class="product-details-available">
# <span class="text-danger"><b>Available:</b> 0</span>
# </div>
# {'category': 'Shooting', 'sub_category': 'Airguns and Accessories (1)', 'url': '/Categories/List/Airguns-and-Accessories'}
# Status Code: 200
# Product 1:
#   Name: BenchMaster Eight Gun Vertical Pistol Rack
#   SKU: 1005803
# {'category': 'Shooting', 'sub_category': 'Barrels (1)', 'url': '/Categories/List/Barrels'}
# Status Code: 200
# Product 1:
#   Name: Rosco Bloodline 4 in Glock 19 Barrel Non-Threaded
#   SKU: 1134786
# {'category': 'Shooting', 'sub_category': 'Bipods and Monopods (19)', 'url': '/Categories/List/Bipods-and-Monopods'}
# Status Code: 200
# Product 1:
#   Name: Harris BiPod Hinged Base 6-9 inches S-BR
#   SKU: 113076
# Product 2:
#   Name: Harris BiPod Hinged Base 9-13 inches S-LM
#   SKU: 012133
# Product 3:
#   Name: Harris Bipod Adapter Flat Bottom 2-4in
#   SKU: 1150374
# Product 4:
#   Name: Harris Bipod 1A2-BR2 Rotate Self Level 6-9 in
#   SKU: 1131711
# Product 5:
#   Name: Harris Bipod Adapter Mini 30 and 14
#   SKU: 1150369
# Product 6:
#   Name: Harris Bipod Adapter Remington 4-74-7400
#   SKU: 1150375
# Product 7:
#   Name: Harris Bipod Adapter AR-15 Round H G
#   SKU: 1150368
# Product 8:
#   Name: Harris S-25CPCAMO Krptek Picatinny 13.5-27 in
#   SKU: 1131710
# Product 9:
#   Name: Harris S-L M-LOK 9-13 in Rotating Bipod
#   SKU: 1134465
# Product 10:
#   Name: Harris Bipod Adapter Flange Nut
#   SKU: 1150378
# Product 11:
#   Name: Harris Bipod Adapter Round Flange Nut
#   SKU: 1150377
# Product 12:
#   Name: Harris Bipod Adapter Radius Flange Nut
#   SKU: 1150371
# Product 13:
#   Name: Harris Bipod Adapter Universal Barrel Clamp
#   SKU: 1150372
# Product 14:
#   Name: Harris Bipod Adapter European Rail
#   SKU: 1150370
# Product 15:
#   Name: Harris Bipod Stud Adapter XP-100 Plastic
#   SKU: 1150376
# Product 16:
#   Name: Harris BiPod Solid Base 9-13 inches 1A2-L
#   SKU: 112123
# Product 17:
#   Name: Harris BiPod Hinged Base 12-25 inches S-25
#   SKU: 112260
# Product 18:
#   Name: Caldwell AR Bipod Prone Dessert Prone
#   SKU: 344551
# Product 19:
#   Name: Harris Bipod Adapter Spacer Thin Forend
#   SKU: 1150373
# ERRROR accessing stock 'span.contents[2].text.strip()' in <div class="product-details-available">
# <span class="text-danger"><b>Available:</b> 0</span>
# </div>
# {'category': 'Shooting', 'sub_category': 'Choke Tubes (4)', 'url': '/Categories/List/Choke-Tubes'}
# Status Code: 200
# Product 1:
#   Name: Trulock Choke Optima Plus Federal #7 12 GA TKY
#   SKU: 1129335
# Product 2:
#   Name: Trulock Choke Benelli Crio Plus Federal #7 20 GA TKY
#   SKU: 1129328
# Product 3:
#   Name: Trulock Choke Benelli Crio Plus Federal #7 12 GA TKY
#   SKU: 1129336
# Product 4:
#   Name: Trulock Choke Browning Federal #7 20 GA TKY
#   SKU: 1129332
# {'category': 'Shooting', 'sub_category': 'Chronographs (2)', 'url': '/Categories/List/Chronographs'}
# Status Code: 200
# Product 1:
#   Name: Competition Electronics Prochrono DLX Chronograph
#   SKU: 1128978
# Product 2:
#   Name: Competition Electronics Prochrono LTD Chronograph
#   SKU: 1128979
# {'category': 'Shooting', 'sub_category': 'Ear Protection (13)', 'url': '/Categories/List/Ear-Protection'}
# Status Code: 200
# Product 1:
#   Name: Pro Ears Audiomorphic Plug Small-Black
#   SKU: 1150382
# Product 2:
#   Name: Pro Ears Stealth 28 Hearing Protection and Amplification Grn
#   SKU: 1125676
# Product 3:
#   Name: Walkers 50 Pair Pill Jar Teal
#   SKU: 1125737
# Product 4:
#   Name: Walkers Recon Professional Grade Black
#   SKU: 1150363
# Product 5:
#   Name: Walkers Low Proflie Folding Muff Pink MO
#   SKU: 1125744
# Product 6:
#   Name: Pro Ears Audiomorphic Plug Large-Black
#   SKU: 1150383
# ERROR accessing price '.h3.text.strip()' in <div class="product-details-price">
# <small class="text-dark">Dealer Price:</small>
# </div>
# Product 7:
#   Name: Pro Ears Audiomorphic Plug Large-Orange
#   SKU: 1150381
# Product 8:
#   Name: Pro Ears Audiomorphic Plug Small-Orange
#   SKU: 1150380
# Product 9:
#   Name: Walkers Folding Passive Muff Highlighter Yellow
#   SKU: 1125746
# Product 10:
#   Name: Walkers Ext Folding Range Muff FDE
#   SKU: 1150362
# Product 11:
#   Name: Walkers Recon Professional Grade FDE
#   SKU: 1150364
# Product 12:
#   Name: SureFire Triple Flanged Filtered Earplugs Small 25 Pr Clear
#   SKU: 1127835
# Product 13:
#   Name: Do All Outdoors EarShield 2 Channel Digital BTE
#   SKU: 1003269
# {'category': 'Shooting', 'sub_category': 'Gear Bags (4)', 'url': '/Categories/List/Gear-Bags'}
# Status Code: 200
# Product 1:
#   Name: Osage River Taber Sling Bag - Purple/Gray
#   SKU: 1107990
# Product 2:
#   Name: Vism Tourniquet and Tactical Shear Pouch Red
#   SKU: 1121975
# Product 3:
#   Name: SKB iSeries 0705-3 Single Go Pro Camera Case
#   SKU: 1006805
# Product 4:
#   Name: Osage River Taber Sling Bag - Black/Gray
# ...
#   Name: NcSTAR VG047 M-LOK Folding Vert Grip-Black
#   SKU: 1150503
# Product 8:
#   Name: Vism AR Beavertail Grip w Core Black
#   SKU: 1131849
# {'category': 'Shooting', 'sub_category': 'Gun Care, Cleaning (12)', 'url': '/Categories/List/Gun-Care-Cleaning'}
# Status Code: 200
# Product 1:
#   Name: Birchwood Casey Spanish Perma Blue Liquid Gun Blue 90 ML
#   SKU: 1150327
# Product 2:
#   Name: Birchwood Casey Gun Scrubber Firearm Cleaner 1.25 Oz Aerosol
#   SKU: 1150325
# Product 3:
#   Name: Birchwood Casey Perma Blue Paste Gun Blue 2 oz Tube
#   SKU: 133226
# Product 4:
#   Name: Birchwood Casey Perma Blue Liquid Gun Blue 3 oz
#   SKU: 381411
# Product 5:
#   Name: Birchwood Casey Gun Scrubber 10 Oz Aero 2 Pack
#   SKU: 1125950
# Product 6:
#   Name: Tipton Ultra Jag 22 Caliber
#   SKU: 1127270
# Product 7:
#   Name: Tipton Nope Rope Pull Through Bore Cleaning Rope 7mm
#   SKU: 1129419
# Product 8:
#   Name: Tipton Nope Rope Pull Through Bore Cleaning Rope 6.5mm
#   SKU: 1129418
# Product 9:
#   Name: Birchwood Casey Gun  Scrubber  Firearm Cleaner 13oz
#   SKU: 333442
# Product 10:
#   Name: Birchwood Casey Aluminum Black Touch-Up 3 Oz-No Packaging
#   SKU: 1150326
# ERRROR accessing stock 'span.contents[2].text.strip()' in <div class="product-details-available">
# <span class="text-danger"><b>Available:</b> 0</span>
# </div>
# Product 11:
#   Name: Birchwood Casey Super Black Touch-Up Pen Flat Black 0.33oz
#   SKU: 1003501
# ERRROR accessing stock 'span.contents[2].text.strip()' in <div class="product-details-available">
# <span class="text-danger"><b>Available:</b> 0</span>
# </div>
# Product 12:
#   Name: Birchwood Casey Aluminum Black Touch Up Pen
#   SKU: 1126519
# ERRROR accessing stock 'span.contents[2].text.strip()' in <div class="product-details-available">
# <span class="text-danger"><b>Available:</b> 0</span>
# </div>
# {'category': 'Shooting', 'sub_category': 'Gun Care, Tools (7)', 'url': '/Categories/List/Gun-Care-Tools'}
# Status Code: 200
# Product 1:
#   Name: Lee Precision Handgun Micrometer Adjust Screw
#   SKU: 1150365
# Product 2:
#   Name: Lee Precision Rifle Micrometer Adjust Screw
#   SKU: 1150366
# Product 3:
#   Name: Lee Precision Large Caliber Rifle Micrometer Adjust Screw
#   SKU: 1150367
# Product 4:
#   Name: VISM VTGUTK Ultimate Tool Kit Glock Multi
#   SKU: 1150488
# Product 5:
#   Name: Vism G5+ Glock Pocket Tool
#   SKU: 1121996
# Product 6:
#   Name: NcSTAR XD Slide Vice Block Tool
#   SKU: 1134590
# Product 7:
#   Name: NcSTAR Beretta 92 Pistol Accessory Rail Adapter MADBER
#   SKU: 1150487
# ERRROR accessing stock 'span.contents[2].text.strip()' in <div class="product-details-available">
# <span class="text-danger"><b>Available:</b> 0</span>
# </div>
# {'category': 'Shooting', 'sub_category': 'Gun Cases, Hard (4)', 'url': '/Categories/List/Gun-Cases-Hard'}
# Status Code: 200
# Product 1:
#   Name: SKB iSeries Pistol Case 10 in x 6 in x 3in Cubed Foam Black
#   SKU: 1150259
# Product 2:
#   Name: SKB iSeries Dry Box 9.50 in x 7.38 in x 4.13 in Black
#   SKU: 1150255
# Product 3:
#   Name: SKB iSeries Tool Tech Box w Pull Out Trays and Wheels Black
#   SKU: 1150260
# Product 4:
#   Name: SKB iSeries Single Rifle Case with Convolute Foam Tan
#   SKU: 1150257
# {'category': 'Shooting', 'sub_category': 'Gun Cases, Soft (5)', 'url': '/Categories/List/Gun-Cases-Soft'}
# Status Code: 200
# Product 1:
#   Name: Vism 42 Inch Double Carbine Case-Green
#   SKU: 1122559
# Product 2:
#   Name: Vism Deluxe Double Rifle Case 46 inL X 13 inH-Black
#   SKU: 1122557
# Product 3:
#   Name: Vism 36 Inch Double Carbine Case-Digital Camo
#   SKU: 1122558
# Product 4:
#   Name: Vism Deluxe Double Rifle Case 46 inL x 13 inH-Tan
#   SKU: 1122560
# Product 5:
#   Name: Vism 42 Inch Double Carbine Case-Woodland Camo
#   SKU: 1122884
# {'category': 'Shooting', 'sub_category': 'Holster, Accessories (1)', 'url': '/Categories/List/Holster-Accessories'}
# Status Code: 200
# Product 1:
#   Name: Safariland 6075UBL 55 2 MS22 Low Ride Universal Belt Loop
#   SKU: 1129092
# {'category': 'Shooting', 'sub_category': 'Holsters, Ankle (1)', 'url': '/Categories/List/Holsters-Ankle'}
# Status Code: 200
# Product 1:
#   Name: Fobus Evolution Ankle Holster RUNDA
#   SKU: 4016893
# {'category': 'Shooting', 'sub_category': 'Holsters, Drop Leg (3)', 'url': '/Categories/List/Holsters-Drop-Leg'}
# Status Code: 200
# Product 1:
#   Name: VISM Drop Leg Tactical Holster-Green
#   SKU: 1150489
# Product 2:
#   Name: Safariland 6005 SLS Tactical Holster Black RH
#   SKU: 1129098
# Product 3:
#   Name: Safariland Model 6354DO LH OD Green
#   SKU: 1127439
# {'category': 'Shooting', 'sub_category': 'Holsters, Inside Waistband (1)', 'url': '/Categories/List/Holsters-Inside-Waistband'}
# Status Code: 200
# Product 1:
#   Name: TecGrip FormLok IWB BK Moldable Holster Ambi Size 08
#   SKU: 1133968
# {'category': 'Shooting', 'sub_category': 'Holsters, Outside Waistband (13)', 'url': '/Categories/List/Holsters-Outside-Waistband'}
# Status Code: 200
# Product 1:
#   Name: Blade Tech Fits Glock 29/30 Combo Pack HOLX0076RC2930BLKRH
#   SKU: 5016355
# ERROR accessing price '.h3.text.strip()' in <div class="product-details-price">
# <small class="text-dark">Dealer Price:</small>
# </div>
# Product 2:
#   Name: Safariland 7378 G19 STX Holster Flat Dark Earth LH
#   SKU: 1129016
# Product 3:
#   Name: Hogue ARS Stage 1 Carry Holster Sig Sauer SP2022 LH CF Weave
#   SKU: 1124531
# Product 4:
#   Name: Hogue ARS Stage1 Carry Holster SW MPL 9MM 40SW 357SIG RH Blk
#   SKU: 1124519
# Product 5:
#   Name: Hogue ARS Stage 1 Carry Holster Sig Sauer P225A1 LH Black
#   SKU: 1124523
# Product 6:
#   Name: Hogue ARS Stage 1 Carry Holster Sig Sauer P229 LH CF Weave
#   SKU: 1124532
# Product 7:
#   Name: Safariland 6378 ALS Concealment Paddle Holster STX RH
#   SKU: 1129040
# Product 8:
#   Name: Hogue ARS Stage 2 Duty Holster CZ P10 Compact RH Black
#   SKU: 1124510
# Product 9:
#   Name: Safariland 6378 ALS Concealment Paddle Holster STX RH
#   SKU: 1129034
# Product 10:
#   Name: Blade Tech Fits SIG 220/220R Combo Pack HOLX0076RCS220BLKRH
#   SKU: 5016353
# ERROR accessing price '.h3.text.strip()' in <div class="product-details-price">
# <small class="text-dark">Dealer Price:</small>
# </div>
# Product 11:
#   Name: Hogue ARS Stage 1 Holster Beretta PX4 Storm Full Comp RH Blk
#   SKU: 1124521
# Product 12:
#   Name: Hogue ARS Stage 1 Carry Holster Sig Sauer P229 LH Black
#   SKU: 1124524
# Product 13:
#   Name: Blade Tech Combo Pack Holster Springfield XD 9 40 4in Black
#   SKU: 5016356
# ERROR accessing price '.h3.text.strip()' in <div class="product-details-price">
# <small class="text-dark">Dealer Price:</small>
# </div>
# {'category': 'Shooting', 'sub_category': 'Mag Pouches and Dump Bags (1)', 'url': '/Categories/List/Mag-Pouches-and-Dump-Bags'}
# Status Code: 200
# Product 1:
#   Name: Foundation Series Black Single 7.62 Magazine Pouch
#   SKU: 1133998
# {'category': 'Shooting', 'sub_category': 'Magazines (33)', 'url': '/Categories/List/Magazines'}
# Status Code: 200
# Product 1:
#   Name: Mec-Gar CZ 75B 85B SP-01 9mm 17rd Flush Anti-Friction Mag
#   SKU: 1123626
# Product 2:
#   Name: ProMag Canik TP9 9mm 18 Round Magazine-Blued Steel
#   SKU: 1125404
# Product 3:
#   Name: Mec-Gar CZ 75B 85B SP-01 9mm 16rd Blued Magazine
#   SKU: 1123640
# Product 4:
#   Name: Mec-Gar S and W 5900 Series 915 910 695 9mm 15rd Blued Mag
#   SKU: 1123653
# Product 5:
#   Name: Mec-Gar SW 5900 Series 915 910 695 9mm 17rd Flush Blued Mag
#   SKU: 1123654
# Product 6:
#   Name: ProMag Ruger LCP .380 ACP 15 Round Magazine-Blued Steel
#   SKU: 1125229
# Product 7:
#   Name: ProMag Archangel LVX SKS Rifle 7.62x39mm 20 Round Magazine
#   SKU: 1125409
# Product 8:
#   Name: Mec-Gar Sis Sauer P.229-1 9mm 17rd Extend Anti-Friction Mag
#   SKU: 1123647
# Product 9:
#   Name: ProMag Akdal MKA 1919 12 Gauge 2.75 3 in 10 Round Mag-Black
#   SKU: 1125339
# Product 10:
#   Name: ProMag Remington Model 597 .22 Long Rifle 70 Round Drum Mag
#   SKU: 1125408
# Product 11:
#   Name: ProMag Ruger 10 22 Charger .22 Long Rifle 70 Round Drum Mag
#   SKU: 1125344
# Product 12:
#   Name: ProMag Springfield Armory XD-M 9mm 32 Round Magazine
#   SKU: 1125361
# Product 13:
#   Name: ProMag Colt 1911 Government .45 ACP 15 Round Mag-Blued Steel
#   SKU: 1125221
# Product 14:
#   Name: ProMag Walther P99 SW99 9mm 50 Round Drum Black Polymer Mag
#   SKU: 1135420
# Product 15:
#   Name: ProMag FN 509 Compact 9mm 12 Round Blue Steel Magazine
#   SKU: 1135383
# Product 16:
#   Name: ProMag FN 509 Compact 9mm 15 Round Blue Steel Magazine
#   SKU: 1135384
# Product 17:
#   Name: ProMag FN SCAR 17 .308 20 Round Flat Dark Earth Polymer Mag
#   SKU: 1135388
# Product 18:
#   Name: ProMag Akdal MKA 1923 12 Gauge 2.75 in 10 Round Magazine
#   SKU: 1125427
# Product 19:
#   Name: ProMag Ruger Mini-14 .223 Caliber 10 Round Magazine
#   SKU: 1125241
# Product 20:
#   Name: ProMag Ruger 10 22 Charger .22 Long Rifle 55 Round Drum Mag
#   SKU: 1125343
# Product 21:
#   Name: ProMag Saiga 12 Gauge 10 Round Magazine-Black
#   SKU: 1125233
# Product 22:
#   Name: ProMag Sig Sauer P320 9mm 17 Round Magazine-Blued Steel
#   SKU: 1125399
# Product 23:
#   Name: ProMag Archangel LVX SKS Rifle 7.62x39mm 35 Rnd Mag
#   SKU: 1125376
# Product 24:
#   Name: ProMag US M1 Carbine .30 Carbine 30 Rounds-Blued Steel
#   SKU: 1125215
# Product 25:
#   Name: ProMag AR-308 .308 Caliber 50 Round Drum Magazine
#   SKU: 1125412
# {'category': 'Shooting', 'sub_category': 'Rails, Mounts and Adaptors (16)', 'url': '/Categories/List/Rails-Mounts-and-Adaptors'}
# Status Code: 200
# Product 1:
#   Name: Troy Battlerail SOCC92 12.5 in Spec Ops M-LOK Low Pro-Black
#   SKU: 1134528
# Product 2:
#   Name: Troy Battlerail SOCC92 12.5 in Spec Ops M-LOK Low Pro-FDE
#   SKU: 1134529
# Product 3:
#   Name: Troy Battlerail SOCC92 15.125 in Spec Ops M-LOK Low Pro-Blk
#   SKU: 1134530
# Product 4:
#   Name: Troy Battlerail SOCC92 9.25 in Spec Ops M-LOK Low Pro-Black
#   SKU: 1134524
# Product 5:
#   Name: Troy Battlerail M-LOK 5.56 Aluminum 13 in-Black
#   SKU: 1134534
# Product 6:
#   Name: Troy Battlerail M-LOK 308 HP Aluminum 15 in-Black
#   SKU: 1134540
# Product 7:
#   Name: Troy Battlerail SOCC92 10.25 in Spec Ops M-LOK Low Pro-Black
#   SKU: 1134526
# Product 8:
#   Name: Leapers UTG PRO 1.57in 4 Slot Keymod Picatinny Rail Section
#   SKU: 1124680
# Product 9:
#   Name: Troy Battlerail M-LOK 5.56 Aluminum 13 in-FDE
#   SKU: 1134535
# Product 10:
#   Name: Troy Battlerail Rail Section M-LOK 3 in
#   SKU: 1134548
# Product 11:
#   Name: Vism M-LOK Accessory Rail-Short
#   SKU: 1121992
# Product 12:
#   Name: Troy Battlerail M-LOK 5.56 Aluminum 15 in-FDE
#   SKU: 1134537
# Product 13:
#   Name: Troy Battlerail M-LOK 308 HP Aluminum 13 in-Black
#   SKU: 1134538
# Product 14:
#   Name: Troy Battlerail M-LOK 308 LP Aluminum 13 in-Black
#   SKU: 1134541
# Product 15:
#   Name: Troy Alpha Rail 9 in-Black
#   SKU: 1134543
# Product 16:
#   Name: NcSTAR Ruger Mini 14 Picatinny Rail Mount-Black-GEN 2
#   SKU: 1121981
# ERRROR accessing stock 'span.contents[2].text.strip()' in <div class="product-details-available">
# <span class="text-danger"><b>Available:</b> 0</span>
# </div>
# {'category': 'Shooting', 'sub_category': 'Reloading (78)', 'url': '/Categories/List/Reloading'}
# Status Code: 200
# Product 1:
#   Name: Lee Precision Powder Measure Kit
#   SKU: 1109327
# Product 2:
#   Name: Lee Precision Case Condtion Combo
#   SKU: 1134010
# Product 3:
#   Name: Lee Precision 308 Factory Crimp Die
#   SKU: 1150295
# Product 4:
#   Name: Lee Precision 308 Win Gauge Holder
#   SKU: 1150287
# Product 5:
#   Name: Lee Precision Charging Die Kit
#   SKU: 1134031
# Product 6:
#   Name: Lee Precision Cutter and Lock Stud
#   SKU: 1134025
# Product 7:
#   Name: Lee Precision  91193 Bullet Seating Die 45 ACP
#   SKU: 1150312
# Product 8:
#   Name: Lee Precision Pacesetter Dies .308
#   SKU: 905071
# Product 9:
#   Name: Lee Precision 6.5 Grendel Pacesetter
#   SKU: 1134018
# Product 10:
#   Name: Lee Precision Ingot Mold
#   SKU: 1134026
# Product 11:
#   Name: Lee Precision Reloading Gauge Holder 300 AAC Blackout
#   SKU: 1150271
# Product 12:
#   Name: Lee Precision 91056 FL Size Die 270 Win
#   SKU: 1150316
# Product 13:
#   Name: Lee Precision 223 Rem Gauge Holder
#   SKU: 1150307
# Product 14:
#   Name: Lee Precision Breech Lock Pro Shell Plate 2
#   SKU: 1130875
# Product 15:
#   Name: LEE PRECISION 91969 AP1987A Small Adapter Assembly
#   SKU: 1150266
# Product 16:
#   Name: Lee Precision .356 Bullet Lube and Size Kit
#   SKU: 1134030
# Product 17:
#   Name: Lee Precision 91922 Pacesetter Dies 8.6 Blackout
#   SKU: 1150290
# Product 18:
#   Name: Lee Precision 12-Gauge Sizer Load All
#   SKU: 1150269
# Product 19:
#   Name: Lee Precision Modern Reloading Manual 2nd Edition
#   SKU: 1130868
# Product 20:
#   Name: Lee Precision 50Cal 320RB Double Cavity Mold
#   SKU: 1150314
# Product 21:
#   Name: Lee Precision 91035 FL Size Die 223 Rem
#   SKU: 1150289
# Product 22:
#   Name: Lee Precision  90047 Sizing Die Kit .357
#   SKU: 1150324
# Product 23:
#   Name: Lee Precision 20-Gauge Sizer Load All
#   SKU: 1150275
# Product 24:
#   Name: Lee Precision R2 Shell Holder
#   SKU: 1150286
# Product 25:
#   Name: Lee Precision R4 Shell Holder
#   SKU: 1150276
# {'category': 'Shooting', 'sub_category': 'Safes and Accessories (2)', 'url': '/Categories/List/Safes-and-Accessories'}
# Status Code: 200
# Product 1:
#   Name: Lockdown AR 15 Magazine Rack
#   SKU: 1001349
# Product 2:
#   Name: Benchmaster Weapon Rack Concealed Pistol Storage Holster
#   SKU: 1109860
# {'category': 'Shooting', 'sub_category': 'Shooting Rests and Benches (2)', 'url': '/Categories/List/Shooting-Rests-and-Benches'}
# Status Code: 200
# Product 1:
#   Name: Benchmaster Weapon Rack X-Block -Gun Rest - Bench Shooting
#   SKU: 1109866
# Product 2:
#   Name: Benchmaster Weapon Rack X-BLOCK XL Shooting Rest
#   SKU: 1130295
# ERRROR accessing stock 'span.contents[2].text.strip()' in <div class="product-details-available">
# <span class="text-danger"><b>Available:</b> 0</span>
# </div>
# {'category': 'Shooting', 'sub_category': 'Sights (5)', 'url': '/Categories/List/Sights'}
# Status Code: 200
# Product 1:
#   Name: TruGlo Tritium Pro Glock 42 43 MOS Set White
#   SKU: 1135640
# Product 2:
#   Name: TruGlo Bow Jack LW Folding Bow Stand Mini Wide Black Red
#   SKU: 1150357
# Product 3:
#   Name: TruGlo TFX Rugar SR Set Pro ORN Handgun Sight
#   SKU: 1007616
# Product 4:
#   Name: TruGlo Tritium Pro Glock MOS Low Set Orange
#   SKU: 1150359
# Product 5:
#   Name: Troy Fixed M4 Front Sight-Black
#   SKU: 1134556
# Product 6:
#   Name: TruGlo Tritium Pro Glock Mos Hi Set Orange
#   SKU: 1150358
# Product 7:
#   Name: TruGlo TFX Pro CZ P10 Set
#   SKU: 1150355
# ERRROR accessing stock 'span.contents[2].text.strip()' in <div class="product-details-available">
# <span class="text-danger"><b>Available:</b> 0</span>
# </div>
# Product 8:
#   Name: TruGlo TFX Steyr Set Pro ORN Handgun Sight
#   SKU: 1007620
# ERRROR accessing stock 'span.contents[2].text.strip()' in <div class="product-details-available">
# <span class="text-danger"><b>Available:</b> 0</span>
# </div>
# {'category': 'Shooting', 'sub_category': 'Slings and Swivels (1)', 'url': '/Categories/List/Slings-and-Swivels'}
# Status Code: 200
# Product 1:
#   Name: Troy OEM Sling Mount-FDE
#   SKU: 810266
# {'category': 'Shooting', 'sub_category': 'Snap Caps (1)', 'url': '/Categories/List/Snap-Caps'}
# Status Code: 200
# Product 1:
#   Name: Carlson Snap Caps .223 2 pack
#   SKU: 1122006
# {'category': 'Shooting', 'sub_category': 'Stocks (4)', 'url': '/Categories/List/Stocks'}
# Status Code: 200
# Product 1:
#   Name: ProMag Archangel Op AK-47 AKM Buttstck Forend PistolGrip Set
#   SKU: 1125383
# Product 2:
#   Name: ProMag Archangel AdjustButtstock Rem 870 12Ga w 7Rnd Carrier
#   SKU: 1125370
# Product 3:
#   Name: ProMag Archangel Precision Stock Ruger Mini 14 Mini Thirty
#   SKU: 1125357
# Product 4:
#   Name: ProMag Archangel Low-Pro Buttstock AR-15 w Commercial Tube
#   SKU: 1125373
# {'category': 'Shooting', 'sub_category': 'Targets (1)', 'url': '/Categories/List/Targets'}
# Status Code: 200
# Product 1:
#   Name: Caldwell 8in Sight-In Target 25 Sheets
#   SKU: 1132828
# Product 2:
#   Name: Birchwood Casey Eze-Scorer 23in X 35in Mule Deer-2 Pack
#   SKU: 1150328
# {'category': 'Shooting', 'sub_category': 'Trap Throwers (1)', 'url': '/Categories/List/Trap-Throwers'}
# Status Code: 200
# Product 1:
#   Name: Caldwell Clay Launcher
#   SKU: 1127257
# {'category': 'Sports', 'sub_category': 'Softball (1)', 'url': '/Categories/List/Softball'}
# Status Code: 200
# Product 1:
#   Name: EvilSports Microcell Tech 44-375 Softball (Dozen)
#   SKU: 44808965226675
# ERROR accessing price '.h3.text.strip()' in <div class="product-details-price">
# <small class="text-dark">Dealer Price:</small>
# </div>

# %%
type(dfs),type(dfs[1])
# Out:
# (dict, pandas.core.frame.DataFrame)

# %%
merged_df1 = pd.concat([df for df in dfs.values()], ignore_index=True)

len(merged_df1)
merged_df1.head()
# Out:
#        SKU                                               Name  \
# 0  1108232  5.11 Tactical Stryke Pant w/Flex-Tac -TDU Gree...
# 1  1121604          ESS Crosshair Replacement Lens Smoke Gray
# 2  1121609                              ESS Nomex Heat Sleeve
# 3  1121597        ESS Crossbow Replacement Lens Hi-Def Yellow
# 4   311926  ESS Eyewear Profile NVG Hi-Def Yelllow Rep Len...
#
#                                          Description   Price Stock  \
# 0  Durable, flexible professional cargo pants\nCo...  $79.99     1
# 1  VLT: 15 percent\nLens tint: Smoke Grey\nInclud...  $20.00    18
# 2  Heat resistant Nomex\nProtects goggle\nScratch...  $25.00     6
# 3  Includes mirco fiber storage sleeve\nLens tint...  $30.00     6
# 4  Hi-Def Yellow Lens\n2.8mm\n100% UVA/UVB protec...  $22.00     5
#
#                                     Link category           sub_category
# 0  https://ssisports.net/Products/346397  Apparel                Bottoms
# 1  https://ssisports.net/Products/439637  Apparel  Eyewear - Accessories
# 2  https://ssisports.net/Products/439642  Apparel  Eyewear - Accessories
# 3  https://ssisports.net/Products/439631  Apparel  Eyewear - Accessories
# 4   https://ssisports.net/Products/73681  Apparel  Eyewear - Accessories

# %%
merged_df = pd.concat(dfs.values(), ignore_index=True)

len(merged_df)
merged_df.head()
# Out:
#        SKU                                               Name  \
# 0  1108232  5.11 Tactical Stryke Pant w/Flex-Tac -TDU Gree...
# 1  1121604          ESS Crosshair Replacement Lens Smoke Gray
# 2  1121609                              ESS Nomex Heat Sleeve
# 3  1121597        ESS Crossbow Replacement Lens Hi-Def Yellow
# 4   311926  ESS Eyewear Profile NVG Hi-Def Yelllow Rep Len...
#
#                                          Description   Price Stock  \
# 0  Durable, flexible professional cargo pants\nCo...  $79.99     1
# 1  VLT: 15 percent\nLens tint: Smoke Grey\nInclud...  $20.00    18
# 2  Heat resistant Nomex\nProtects goggle\nScratch...  $25.00     6
# 3  Includes mirco fiber storage sleeve\nLens tint...  $30.00     6
# 4  Hi-Def Yellow Lens\n2.8mm\n100% UVA/UVB protec...  $22.00     5
#
#                                     Link category           sub_category
# 0  https://ssisports.net/Products/346397  Apparel                Bottoms
# 1  https://ssisports.net/Products/439637  Apparel  Eyewear - Accessories
# 2  https://ssisports.net/Products/439642  Apparel  Eyewear - Accessories
# 3  https://ssisports.net/Products/439631  Apparel  Eyewear - Accessories
# 4   https://ssisports.net/Products/73681  Apparel  Eyewear - Accessories

# %%
from util.gsheet import update_sheet,list_available_spreadsheets,update_sheet_by_id

# %%
list_available_spreadsheets()
# Out:
# Available spreadsheets:
# 1. AutoProductList (ID: 1ZE7BeE26iM43x_ympaIgOdl6lXWrwXg-PZZAKuIBEIw)
# [<Spreadsheet 'AutoProductList' id:1ZE7BeE26iM43x_ympaIgOdl6lXWrwXg-PZZAKuIBEIw>]

# %%
from util.gsheet import update_sheet_by_id

sheet_id = "1ZE7BeE26iM43x_ympaIgOdl6lXWrwXg-PZZAKuIBEIw"
sheet_name = "Sheet20"

update_sheet_by_id(merged_df, sheet_id, sheet_name)
# Out:
# Data successfully uploaded to Google Sheets!

# %%
# for category in categories:
#     if "Shooting" in category.find('h1').text:
#         print(category.text)
#         break

# %%
# cat = category.find('h1').text.strip()
# sub_cats_html = category.find_all(class_='brand-section-brand')

# for sub_cat in sub_cats_html:
#     a_tag = sub_cat.find('a')
#     if a_tag:
#         sub_cat_name = a_tag.text.strip()
#         sub_cat_url = a_tag['href']
#         print(sub_cat_name, sub_cat_url)
